# %% [markdown]
# <a href="https://colab.research.google.com/github/samikshak02/Python-Basic-Projects./blob/master/Optionaltask18_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Loading & Initial Analysis

# %%
from google.colab import files
uploaded= files.upload()
filepath="/content/Teen_Mental_Health_Dataset.csv"
df=pd.read_csv(filepath)
# Out:
#      <input type="file" id="files-315840bb-c161-4efe-be9e-f09ab5c602e1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-315840bb-c161-4efe-be9e-f09ab5c602e1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.head()
# Out:
#    age  gender  daily_social_media_hours platform_usage  sleep_hours  \
# 0   14    male                       7.9      Instagram          7.4
# 1   19  female                       1.9         TikTok          8.0
# 2   17  female                       1.3      Instagram          7.6
# 3   15    male                       7.4         TikTok          6.9
# 4   15  female                       4.7           Both          4.9
#
#    screen_time_before_sleep  academic_performance  physical_activity  \
# 0                       2.9                  3.01                1.5
# 1                       2.9                  3.22                0.8
# 2                       0.5                  3.92                0.0
# 3                       1.6                  3.48                0.8
# 4                       3.0                  2.37                1.4
#
#   social_interaction_level  stress_level  anxiety_level  addiction_level  \
# ...

# %%
df.tail()
# Out:
#       age  gender  daily_social_media_hours platform_usage  sleep_hours  \
# 1195   18  female                       6.8      Instagram          6.6
# 1196   16    male                       2.3           Both          8.0
# 1197   14  female                       1.7           Both          8.7
# 1198   15    male                       3.9           Both          8.5
# 1199   16  female                       4.7         TikTok          6.5
#
#       screen_time_before_sleep  academic_performance  physical_activity  \
# 1195                       2.0                  2.76                1.0
# 1196                       1.9                  2.12                0.4
# 1197                       0.7                  3.98                0.8
# 1198                       2.1                  3.19                0.6
# 1199                       1.0                  2.91                0.9
#
#      social_interaction_level  stress_level  anxiety_level  addiction_level  \
# ...

# %%
df.shape
# Out:
# (1200, 13)

# %%
df.dtypes
# Out:
# age                           int64
# gender                       object
# daily_social_media_hours    float64
# platform_usage               object
# sleep_hours                 float64
# screen_time_before_sleep    float64
# academic_performance        float64
# physical_activity           float64
# social_interaction_level     object
# stress_level                  int64
# anxiety_level                 int64
# addiction_level               int64
# depression_label              int64
# dtype: object

# %% [markdown]
# ## Missing & Duplicate Values

# %%
print("Duplicate Rows:", df.duplicated().sum())
# Out:
# Duplicate Rows: 0

# %%
df = df.drop_duplicates()
print("New Shape:", df.shape)
# Out:
# New Shape: (1200, 13)

# %% [markdown]
# # Statistical Summary

# %%
df.describe()
# Out:
#                age  daily_social_media_hours  sleep_hours  \
# count  1200.000000               1200.000000  1200.000000
# mean     15.928333                  4.536667     6.449417
# std       2.021947                  2.029599     1.442677
# min      13.000000                  1.000000     4.000000
# 25%      14.000000                  2.800000     5.200000
# 50%      16.000000                  4.500000     6.500000
# 75%      18.000000                  6.300000     7.600000
# max      19.000000                  8.000000     9.000000
#
#        screen_time_before_sleep  academic_performance  physical_activity  \
# count               1200.000000           1200.000000        1200.000000
# mean                   1.740333              2.990383           1.014500
# std                    0.716660              0.576758           0.582185
# min                    0.500000              2.000000           0.000000
# 25%                    1.100000              2.500000           0.500000
# ...

# %%
df[['age','sleep_hours','screen_time_before_sleep']].min()
# Out:
# age                         13.0
# sleep_hours                  4.0
# screen_time_before_sleep     0.5
# dtype: float64

# %%
df[['age','sleep_hours','screen_time_before_sleep']].max()
# Out:
# age                         19.0
# sleep_hours                  9.0
# screen_time_before_sleep     3.0
# dtype: float64

# %%
df[['age','sleep_hours','screen_time_before_sleep']].mean()
# Out:
# age                         15.928333
# sleep_hours                  6.449417
# screen_time_before_sleep     1.740333
# dtype: float64

# %%
df[['age','sleep_hours','screen_time_before_sleep']].median()
# Out:
# age                         16.0
# sleep_hours                  6.5
# screen_time_before_sleep     1.8
# dtype: float64

# %% [markdown]
# # Histogram of Numeric Features

# %%
plt.hist(df["age"], bins=10)
plt.title("Histogram of Age")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %%
sns.countplot(x="gender", data=df)
plt.title("Count Plot of Gender")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # Correlation Heatmap

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.title("Correlation Heatmap")
plt.xlabel("Features")
plt.ylabel("Features")
plt.show()

# %%
X = df.drop('depression_label', axis=1)
Y = df['depression_label']
print("input Features:")
print(X.columns)
print("\nOutput Feature:")
print(Y.name)
# Out:
# input Features:
# Index(['age', 'gender', 'daily_social_media_hours', 'platform_usage',
#        'sleep_hours', 'screen_time_before_sleep', 'academic_performance',
#        'physical_activity', 'social_interaction_level', 'stress_level',
#        'anxiety_level', 'addiction_level'],
#       dtype='object')
#
# Output Feature:
# depression_label

# %% [markdown]
# # Encoding Categorical Variables

# %%
encoded= pd.get_dummies(df)
print(encoded.head())
# Out:
#    age  daily_social_media_hours  sleep_hours  screen_time_before_sleep  \
# 0   14                       7.9          7.4                       2.9
# 1   19                       1.9          8.0                       2.9
# 2   17                       1.3          7.6                       0.5
# 3   15                       7.4          6.9                       1.6
# 4   15                       4.7          4.9                       3.0
#
#    academic_performance  physical_activity  stress_level  anxiety_level  \
# 0                  3.01                1.5             2              2
# 1                  3.22                0.8             8              1
# 2                  3.92                0.0             2              4
# 3                  3.48                0.8             1              7
# 4                  2.37                1.4             3              5
#
#    addiction_level  depression_label  gender_female  gender_male  \
# ...
