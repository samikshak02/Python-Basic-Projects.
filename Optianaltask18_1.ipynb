# %% [markdown]
# <a href="https://colab.research.google.com/github/samikshak02/Python-Basic-Projects./blob/master/Optianaltask18_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Loading & Initial Analysis

# %%
from google.colab import files
uploaded= files.upload()
filepath="/content/insurance.csv"
df=pd.read_csv(filepath)
# Out:
#      <input type="file" id="files-6840c04b-2639-4a16-9197-0986bddcca71" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6840c04b-2639-4a16-9197-0986bddcca71">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
df.tail()
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# expenses    float64
# dtype: object

# %% [markdown]
# ## Missing & Duplicate Values

# %%
print("Duplicate Rows:", df.duplicated().sum())
# Out:
# Duplicate Rows: 1

# %%
df = df.drop_duplicates()

# %%
print("New Shape:", df.shape)
# Out:
# New Shape: (1337, 7)

# %% [markdown]
# # Statistical Summary

# %%
df.describe()
# Out:
#                age          bmi     children      expenses
# count  1337.000000  1337.000000  1337.000000   1337.000000
# mean     39.222139    30.665520     1.095737  13279.121638
# std      14.044333     6.100664     1.205571  12110.359657
# min      18.000000    16.000000     0.000000   1121.870000
# 25%      27.000000    26.300000     0.000000   4746.340000
# 50%      39.000000    30.400000     1.000000   9386.160000
# 75%      51.000000    34.700000     2.000000  16657.720000
# max      64.000000    53.100000     5.000000  63770.430000

# %%
df[['age','bmi','expenses']].min()
# Out:
# age           18.00
# bmi           16.00
# expenses    1121.87
# dtype: float64

# %%
df[['age','bmi','expenses']].max()
# Out:
# age            64.00
# bmi            53.10
# expenses    63770.43
# dtype: float64

# %%
df[['age','bmi','expenses']].mean()
# Out:
# age            39.222139
# bmi            30.665520
# expenses    13279.121638
# dtype: float64

# %%
df[['age','bmi','expenses']].median()
# Out:
# age           39.00
# bmi           30.40
# expenses    9386.16
# dtype: float64

# %% [markdown]
# # Histogram of Numeric Features

# %%
sns.histplot(df['age'])
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
sns.histplot(df["children"])
plt.title("Children Distribution")
plt.xlabel("Children")
plt.ylabel("Count")
plt.show()

# %%
sns.histplot(df["expenses"])
plt.title("expenses Distribution")
plt.xlabel("expenses")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # Count Plots of Categorical Features

# %%
sns.countplot(x="sex", data=df)
plt.title("Sex Count")
plt.xlabel("Sex")
plt.ylabel("Count")
plt.show()

# %%
sns.countplot(x="smoker", data=df)
plt.title("Smoker Count")
plt.xlabel("Smoker")
plt.ylabel("Count")
plt.show()

# %%
sns.countplot(x="region", data=df)
plt.title("Region Count")
plt.xlabel("Region")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # Correlation Heatmap

# %%
sns.heatmap(df.corr(numeric_only=True))
plt.title("Heatmap")
plt.show()

# %% [markdown]
# # Identify input and output features .

# %%
X = df.drop('expenses', axis=1)
Y = df['expenses']

print("input Features:")
print(X.columns)
print("\nOutput Feature:")
print(Y.name)
# Out:
# input Features:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region'], dtype='object')
#
# Output Feature:
# expenses

# %% [markdown]
# # Encoding Categorical Variables

# %%
encoded= pd.get_dummies(df)
print(encoded.head())
# Out:
#    age   bmi  children  expenses  sex_female  sex_male  smoker_no  smoker_yes  \
# 0   19  27.9         0  16884.92        True     False      False        True
# 1   18  33.8         1   1725.55       False      True       True       False
# 2   28  33.0         3   4449.46       False      True       True       False
# 3   33  22.7         0  21984.47       False      True       True       False
# 4   32  28.9         0   3866.86       False      True       True       False
#
#    region_northeast  region_northwest  region_southeast  region_southwest
# 0             False             False             False              True
# 1             False             False              True             False
# 2             False             False              True             False
# 3             False              True             False             False
# 4             False              True             False             False
