# %% [markdown]
# <a href="https://colab.research.google.com/github/samikshak02/Python-Basic-Projects./blob/master/Special.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Loading & Initial Analysis

# %%
from google.colab import files
uploaded= files.upload()
filepath="/content/ford_car_dataset.csv"
df=pd.read_csv(filepath)
# Out:
#      <input type="file" id="files-9e42e93f-cf5e-4ea8-9616-b3d6d1311a8e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9e42e93f-cf5e-4ea8-9616-b3d6d1311a8e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.head(10)
# Out:
#      model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0   Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7         1.0
# 1    Focus  2018  14000       Manual     9083   Petrol  150  57.7         1.0
# 2    Focus  2017  13000       Manual    12456   Petrol  150  57.7         1.0
# 3   Fiesta  2019  17500       Manual    10460   Petrol  145  40.3         1.5
# 4   Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7         1.0
# 5   Fiesta  2015  10500       Manual    35432   Petrol  145  47.9         1.6
# 6     Puma  2019  22500       Manual     2029   Petrol  145  50.4         1.0
# 7   Fiesta  2017   9000       Manual    13054   Petrol  145  54.3         1.2
# 8     Kuga  2019  25500    Automatic     6894   Diesel  145  42.2         2.0
# 9    Focus  2018  10000       Manual    48141   Petrol  145  61.4         1.0

# %%
df.tail(5)
# Out:
#         model  year  price transmission  mileage fuelType  tax   mpg  \
# 17961   B-MAX  2017   8999       Manual    16700   Petrol  150  47.1
# 17962   B-MAX  2014   7499       Manual    40700   Petrol   30  57.7
# 17963   Focus  2015   9999       Manual     7010   Diesel   20  67.3
# 17964      KA  2018   8299       Manual     5007   Petrol  145  57.7
# 17965   Focus  2015   8299       Manual     5007   Petrol   22  57.7
#
#        engineSize
# 17961         1.4
# 17962         1.0
# 17963         1.6
# 17964         1.2
# 17965         1.0

# %%
df.shape
# Out:
# (17812, 9)

# %%
df.dtypes
# Out:
# model            object
# year              int64
# price             int64
# transmission     object
# mileage           int64
# fuelType         object
# tax               int64
# mpg             float64
# engineSize      float64
# dtype: object

# %% [markdown]
# ## Missing & Duplicate Values

# %%
df.isnull().sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
print("Duplicate Rows:", df.duplicated().sum())
# Out:
# Duplicate Rows: 0

# %%
df = df.drop_duplicates()

# %%
print("New Shape:", df.shape)
# Out:
# New Shape: (17812, 9)

# %%
# Summary:
# Missing values checked using isnull().
# Duplicate rows removed using drop_duplicates()

# %% [markdown]
# # Statistical Summary

# %%
df.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  17812.000000  17812.000000   17812.000000  17812.000000  17812.000000
# mean    2016.862396  12269.556310   23381.146362    113.315012     57.908696
# std        2.052039   4736.285417   19419.011045     62.034603     10.132696
# min     1996.000000    495.000000       1.000000      0.000000     20.800000
# 25%     2016.000000   8999.000000   10000.000000     30.000000     52.300000
# 50%     2017.000000  11288.000000   18277.000000    145.000000     58.900000
# 75%     2018.000000  15295.000000   31098.500000    145.000000     65.700000
# max     2060.000000  54995.000000  177644.000000    580.000000    201.800000
#
#          engineSize
# count  17812.000000
# mean       1.350623
# std        0.432581
# min        0.000000
# 25%        1.000000
# 50%        1.200000
# 75%        1.500000
# max        5.000000

# %%
df[['price','mileage','year']].min()
# Out:
# price       495
# mileage       1
# year       1996
# dtype: int64

# %%
df[['price','mileage','year']].max()
# Out:
# price       54995
# mileage    177644
# year         2060
# dtype: int64

# %%
df[['price','mileage','year']].mean()
# Out:
# price      12269.556310
# mileage    23381.146362
# year        2016.862396
# dtype: float64

# %%
df[['price','mileage','year']].median()
# Out:
# price      11288.0
# mileage    18277.0
# year        2017.0
# dtype: float64

# %% [markdown]
# # Histogram of Numeric Features

# %%
plt.figure(figsize=(6,4))
plt.hist(df['price'], bins=20)
plt.title("Histogram of Price")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.hist(df['mileage'], bins=20)
plt.title("Histogram of Mileage")
plt.xlabel("Mileage")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.hist(df['year'], bins=20)
plt.title("Histogram of Year")
plt.xlabel("Year")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.hist(df['engineSize'], bins=20)
plt.title("Histogram of Engine Size")
plt.xlabel("Engine Size")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.hist(df['mpg'], bins=20)
plt.title("Histogram of MPG")
plt.xlabel("MPG")
plt.ylabel("Frequency")
plt.show()

# %%
# Findings:
# 1. Most cars are in the low to medium price range, while high-priced cars are fewer.
# 2. Mileage and engine size are mostly concentrated in the middle range.
# 3. Most vehicles are from recent years, indicating a newer car dataset.
# 4. MPG values are generally moderate to high, showing that many cars are fuel-efficient.

# %% [markdown]
# # Count Plots of Categorical Features

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x='model')
plt.title("Count Plot of model")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Correlation Heatmap

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# Observations:
# 1. Features with correlation close to +1 have a strong positive relationship.
# 2. Features with correlation close to -1 have a strong negative relationship.
# 3. Check which features are highly correlated with 'price'.

# %% [markdown]
# # Feature Identification

# %%
X = df.drop('price', axis=1)
y = df['price']

print("Independent Features:")
print(X.columns)
print("\nDependent Feature:")
print(y.name)

# Reason:
# 'price' is the target variable to be predicted.
# All remaining columns are used as input features.
# Out:
# Independent Features:
# Index(['model', 'year', 'transmission', 'mileage', 'fuelType', 'tax', 'mpg',
#        'engineSize'],
#       dtype='object')
#
# Dependent Feature:
# price

# %% [markdown]
# # Encoding Categorical Variables

# %%
encoded= pd.get_dummies(df)
print(encoded.head())
# Out:
#    year  price  mileage  tax   mpg  engineSize  model_ B-MAX  model_ C-MAX  \
# 0  2017  12000    15944  150  57.7         1.0         False         False
# 1  2018  14000     9083  150  57.7         1.0         False         False
# 2  2017  13000    12456  150  57.7         1.0         False         False
# 3  2019  17500    10460  145  40.3         1.5         False         False
# 4  2019  16500     1482  145  48.7         1.0         False         False
#
#    model_ EcoSport  model_ Edge  ...  model_ Transit Tourneo  model_Focus  \
# 0            False        False  ...                   False        False
# 1            False        False  ...                   False        False
# 2            False        False  ...                   False        False
# 3            False        False  ...                   False        False
# 4            False        False  ...                   False        False
#
# ...

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
X = df.drop('price', axis=1)
X_num = X.select_dtypes(include=['int64', 'float64'])
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_num)
print(X_scaled[:5])
# Out:
# [[ 0.06705901 -0.38299351  0.59137991 -0.02059691 -0.81056084]
#  [ 0.55439275 -0.73631699  0.59137991 -0.02059691 -0.81056084]
#  [ 0.06705901 -0.56261635  0.59137991 -0.02059691 -0.81056084]
#  [ 1.0417265  -0.66540511  0.51077747 -1.73785836  0.34532516]
#  [ 1.0417265  -1.12774853  0.51077747 -0.90883559 -0.81056084]]

# %% [markdown]
# # Mini Project

# %%
#load data
df = pd.read_csv("ford_car_dataset.csv")
df=df.dropna()
df=df.drop_duplicates()

# %%
plt.figure(figsize=(6,4))
plt.hist(df['price'], bins=20)
plt.title("Histogram of Price")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.hist(df['mileage'], bins=20)
plt.title("Histogram of Mileage")
plt.xlabel("Mileage")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.hist(df['year'], bins=20)
plt.title("Histogram of Year")
plt.xlabel("Year")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.hist(df['engineSize'], bins=20)
plt.title("Histogram of Engine Size")
plt.xlabel("Engine Size")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.hist(df['mpg'], bins=20)
plt.title("Histogram of MPG")
plt.xlabel("MPG")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# # Count Plots of Categorical Features

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x='model')
plt.title("Count Plot of model")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
X = df.drop('price', axis=1)
y = df['price']

print("Input Features:")
print(X.columns)
print("\noutput Feature:")
print(y.name)
# Out:
# Input Features:
# Index(['model', 'year', 'transmission', 'mileage', 'fuelType', 'tax', 'mpg',
#        'engineSize'],
#       dtype='object')
#
# output Feature:
# price

# %%
encoded= pd.get_dummies(df)
print(encoded.head())
# Out:
#    year  price  mileage  tax   mpg  engineSize  model_ B-MAX  model_ C-MAX  \
# 0  2017  12000    15944  150  57.7         1.0         False         False
# 1  2018  14000     9083  150  57.7         1.0         False         False
# 2  2017  13000    12456  150  57.7         1.0         False         False
# 3  2019  17500    10460  145  40.3         1.5         False         False
# 4  2019  16500     1482  145  48.7         1.0         False         False
#
#    model_ EcoSport  model_ Edge  ...  model_ Transit Tourneo  model_Focus  \
# 0            False        False  ...                   False        False
# 1            False        False  ...                   False        False
# 2            False        False  ...                   False        False
# 3            False        False  ...                   False        False
# 4            False        False  ...                   False        False
#
# ...
