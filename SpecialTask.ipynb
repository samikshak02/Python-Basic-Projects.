# %% [markdown]
# <a href="https://colab.research.google.com/github/samikshak02/Python-Basic-Projects./blob/master/SpecialTask.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
uploaded= files.upload()
# Out:
#      <input type="file" id="files-02aeb84a-8dd8-483d-a53d-cf906e2036cc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-02aeb84a-8dd8-483d-a53d-cf906e2036cc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
filepath="/content/manifest.csv"
df=pd.read_csv(filepath)
df.head()
# Out:
#          date                         daily_dataset_slug  \
# 0  2026-06-16  pokemon-tcg-ai-battle-episodes-2026-06-16
# 1  2026-06-17  pokemon-tcg-ai-battle-episodes-2026-06-17
# 2  2026-06-18  pokemon-tcg-ai-battle-episodes-2026-06-18
# 3  2026-06-19  pokemon-tcg-ai-battle-episodes-2026-06-19
# 4  2026-06-20  pokemon-tcg-ai-battle-episodes-2026-06-20
#
#                                    daily_dataset_url  episode_count  \
# 0  https://www.kaggle.com/datasets/kaggle/pokemon...           1277
# 1  https://www.kaggle.com/datasets/kaggle/pokemon...           7819
# 2  https://www.kaggle.com/datasets/kaggle/pokemon...           6532
# 3  https://www.kaggle.com/datasets/kaggle/pokemon...           5426
# 4  https://www.kaggle.com/datasets/kaggle/pokemon...           5178
#
#    total_bytes  top_avg_score  median_avg_score
# 0   2854565943    1024.643707        627.771126
# 1  21474554811    1259.804498        761.005766
# 2  21474554331    1327.123541        926.601386
# ...

# %%
df.tail()
# Out:
#           date                         daily_dataset_slug  \
# 15  2026-07-01  pokemon-tcg-ai-battle-episodes-2026-07-01
# 16  2026-07-02  pokemon-tcg-ai-battle-episodes-2026-07-02
# 17  2026-07-03  pokemon-tcg-ai-battle-episodes-2026-07-03
# 18  2026-07-04  pokemon-tcg-ai-battle-episodes-2026-07-04
# 19  2026-07-05  pokemon-tcg-ai-battle-episodes-2026-07-05
#
#                                     daily_dataset_url  episode_count  \
# 15  https://www.kaggle.com/datasets/kaggle/pokemon...           5266
# 16  https://www.kaggle.com/datasets/kaggle/pokemon...           5153
# 17  https://www.kaggle.com/datasets/kaggle/pokemon...           5133
# 18  https://www.kaggle.com/datasets/kaggle/pokemon...           4975
# 19  https://www.kaggle.com/datasets/kaggle/pokemon...           5034
#
#     total_bytes  top_avg_score  median_avg_score
# 15  21472709170    1344.584468       1180.260904
# 16  21473785185    1274.779486       1135.927808
# 17  21473781654    1250.921561       1104.464801
# ...

# %%
df.shape
# Out:
# (20, 7)

# %%
df.columns
# Out:
# Index(['date', 'daily_dataset_slug', 'daily_dataset_url', 'episode_count',
#        'total_bytes', 'top_avg_score', 'median_avg_score'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                20 non-null     object
#  1   daily_dataset_slug  20 non-null     object
#  2   daily_dataset_url   20 non-null     object
#  3   episode_count       20 non-null     int64
#  4   total_bytes         20 non-null     int64
#  5   top_avg_score       20 non-null     float64
#  6   median_avg_score    20 non-null     float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 1.2+ KB

# %%
df.describe()
# Out:
#        episode_count   total_bytes  top_avg_score  median_avg_score
# count      20.000000  2.000000e+01      20.000000         20.000000
# mean     5429.350000  2.054203e+10    1314.028501       1004.259774
# std      1193.409678  4.163198e+09      85.725533        141.821615
# min      1277.000000  2.854566e+09    1024.643707        627.771126
# 25%      5115.250000  2.147198e+10    1271.035739       1005.431741
# 50%      5460.500000  2.147315e+10    1329.560805       1026.606392
# 75%      5937.250000  2.147394e+10    1368.085382       1102.183053
# max      7819.000000  2.147476e+10    1411.126738       1180.260904

# %%
df.dtypes
# Out:
# date                   object
# daily_dataset_slug     object
# daily_dataset_url      object
# episode_count           int64
# total_bytes             int64
# top_avg_score         float64
# median_avg_score      float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# date                  0
# daily_dataset_slug    0
# daily_dataset_url     0
# episode_count         0
# total_bytes           0
# top_avg_score         0
# median_avg_score      0
# dtype: int64

# %%
df.nunique()
# Out:
# date                  20
# daily_dataset_slug    20
# daily_dataset_url     20
# episode_count         20
# total_bytes           20
# top_avg_score         20
# median_avg_score      20
# dtype: int64

# %%
df.sample()
# Out:
#          date                         daily_dataset_slug  \
# 6  2026-06-22  pokemon-tcg-ai-battle-episodes-2026-06-22
#
#                                    daily_dataset_url  episode_count  \
# 6  https://www.kaggle.com/datasets/kaggle/pokemon...           5062
#
#    total_bytes  top_avg_score  median_avg_score
# 6  21472042818    1346.785101       1049.009917

# %%
df.sample(3)
# Out:
#           date                         daily_dataset_slug  \
# 16  2026-07-02  pokemon-tcg-ai-battle-episodes-2026-07-02
# 17  2026-07-03  pokemon-tcg-ai-battle-episodes-2026-07-03
# 18  2026-07-04  pokemon-tcg-ai-battle-episodes-2026-07-04
#
#                                     daily_dataset_url  episode_count  \
# 16  https://www.kaggle.com/datasets/kaggle/pokemon...           5153
# 17  https://www.kaggle.com/datasets/kaggle/pokemon...           5133
# 18  https://www.kaggle.com/datasets/kaggle/pokemon...           4975
#
#     total_bytes  top_avg_score  median_avg_score
# 16  21473785185    1274.779486       1135.927808
# 17  21473781654    1250.921561       1104.464801
# 18  21473046866    1258.026805       1101.422470

# %%
df['daily_dataset_url'].value_counts()
# Out:
# daily_dataset_url
# https://www.kaggle.com/datasets/kaggle/pokemon-tcg-ai-battle-episodes-2026-06-16    1
# https://www.kaggle.com/datasets/kaggle/pokemon-tcg-ai-battle-episodes-2026-06-17    1
# https://www.kaggle.com/datasets/kaggle/pokemon-tcg-ai-battle-episodes-2026-06-18    1
# https://www.kaggle.com/datasets/kaggle/pokemon-tcg-ai-battle-episodes-2026-06-19    1
# https://www.kaggle.com/datasets/kaggle/pokemon-tcg-ai-battle-episodes-2026-06-20    1
# https://www.kaggle.com/datasets/kaggle/pokemon-tcg-ai-battle-episodes-2026-06-21    1
# https://www.kaggle.com/datasets/kaggle/pokemon-tcg-ai-battle-episodes-2026-06-22    1
# https://www.kaggle.com/datasets/kaggle/pokemon-tcg-ai-battle-episodes-2026-06-23    1
# https://www.kaggle.com/datasets/kaggle/pokemon-tcg-ai-battle-episodes-2026-06-24    1
# https://www.kaggle.com/datasets/kaggle/pokemon-tcg-ai-battle-episodes-2026-06-25    1
# https://www.kaggle.com/datasets/kaggle/pokemon-tcg-ai-battle-episodes-2026-06-26    1
# ...
