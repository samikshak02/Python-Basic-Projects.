# %% [markdown]
# <a href="https://colab.research.google.com/github/samikshak02/Python-Basic-Projects./blob/master/optional.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded= files.upload()
# Out:
#      <input type="file" id="files-e0a9dd8b-d01f-4c6f-83c4-8acbb4c36008" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e0a9dd8b-d01f-4c6f-83c4-8acbb4c36008">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
filepath="/content/anime-selected-columns.csv"
df=pd.read_csv(filepath)
df.head(10)
# Out:
#    anime_id                               title  score  rank  popularity  \
# 0     28977                            Gintama°   9.05     8         347
# 1     57555        Chainsaw Man Movie: Reze-hen   9.18     2         962
# 2     11061              Hunter x Hunter (2011)   9.03     9           8
# 3     52991                   Sousou no Frieren   9.29     1         121
# 4      9969                            Gintama'   9.02    11         406
# 5     15417                 Gintama': Enchousen   9.02    12         756
# 6     39486                  Gintama: The Final   9.05     7        1512
# 7     38524  Shingeki no Kyojin Season 3 Part 2   9.05     6          21
# 8     34096                            Gintama.   8.98    15         786
# 9     41467           Bleach: Sennen Kessen-hen   8.99    14         353
#
#    members                                           synopsis  start_date  \
# 0   680037  Gintoki, Shinpachi, and Kagura return as the f...  2015-01-01
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   anime_id    10000 non-null  int64
#  1   title       10000 non-null  object
#  2   score       10000 non-null  float64
#  3   rank        10000 non-null  int64
#  4   popularity  10000 non-null  int64
#  5   members     10000 non-null  int64
#  6   synopsis    9998 non-null   object
#  7   start_date  9998 non-null   object
#  8   end_date    9916 non-null   object
#  9   type        10000 non-null  object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 781.4+ KB

# %%
df.describe()
# Out:
#            anime_id         score          rank    popularity       members
# count  10000.000000  10000.000000  10000.000000  10000.000000  1.000000e+04
# mean   24129.128000      6.980589   5000.494000   6490.903700  1.075309e+05
# std    19948.188153      0.619406   2886.898727   4646.309341  2.733514e+05
# min        1.000000      6.050000      1.000000      1.000000  2.260000e+02
# 25%     4055.500000      6.470000   2500.750000   2591.750000  4.270250e+03
# 50%    21406.000000      6.900000   5000.500000   5564.500000  1.817900e+04
# 75%    40028.750000      7.390000   7500.250000   9824.250000  8.469275e+04
# max    62863.000000      9.290000  10000.000000  22184.000000  4.262220e+06

# %%
df.isnull().sum()
# Out:
# anime_id       0
# title          0
# score          0
# rank           0
# popularity     0
# members        0
# synopsis       2
# start_date     2
# end_date      84
# type           0
# dtype: int64

# %%
print("Numerical Columns:")
df.select_dtypes(include=['int64', 'float64']).columns
# Out:
# Numerical Columns:
# Index(['anime_id', 'score', 'rank', 'popularity', 'members'], dtype='object')

# %%
print("\nCategorical Columns:")
df.select_dtypes(include=['object']).columns
# Out:
# Categorical Columns:
# Index(['title', 'synopsis', 'start_date', 'end_date', 'type'], dtype='object')

# %%
sns.histplot(df['score'])
plt.title('score Distribution')
plt.xlabel('score')
plt.ylabel('Frequency')
plt.show()

# %%
sns.histplot(df['rank'])
plt.title('rank Distribution')
plt.xlabel('rank')
plt.ylabel('Frequency')
plt.show()

# %%
sns.countplot(x="type", data=df)
plt.title("Type Count")
plt.xlabel("Type")
plt.ylabel("Count")
plt.show()

# %%
sns.heatmap(df.corr(numeric_only=True))
plt.title("Heatmap")
plt.show()
