# %% [markdown]
# <a href="https://colab.research.google.com/github/samikshak02/Python-Basic-Projects./blob/master/Specialtask2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **#data loading**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded= files.upload()
# Out:
#      <input type="file" id="files-f3bbc5d3-ad26-4c58-a57b-39d9f1a79d00" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f3bbc5d3-ad26-4c58-a57b-39d9f1a79d00">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
filepath="/content/customer_shopping.csv"
df=pd.read_csv(filepath)

# %% [markdown]
# # **data exploring**

# %%
df
# Out:
#      Transaction ID Customer ID Purchase Date  Age  Gender     Location  \
# 0         TXN500000  CUST001440    2023-07-22   52   Other       Indore
# 1         TXN500001  CUST002326    2023-01-16   19  Female  Bhubaneswar
# 2         TXN500002  CUST002680    2023-01-24   40    Male    Bangalore
# 3         TXN500003  CUST001098    2024-09-06   46  Female    Ahmedabad
# 4         TXN500004  CUST003158    2023-10-18   62  Female         Pune
# ...             ...         ...           ...  ...     ...          ...
# 9995      TXN509995  CUST000550    2023-12-21   64    Male      Lucknow
# 9996      TXN509996  CUST003122    2024-05-17   35  Female      Lucknow
# 9997      TXN509997  CUST003322    2024-05-06   34    Male        Noida
# 9998      TXN509998  CUST000523    2023-08-22   36  Female        Patna
# 9999      TXN509999  CUST001343    2024-01-19   33  Female       Mumbai
#
#      Online/Offline       Online Store     Category Item Purchased  Quantity
# ...

# %%
df.head()
# Out:
#   Transaction ID Customer ID Purchase Date  Age  Gender     Location  \
# 0      TXN500000  CUST001440    2023-07-22   52   Other       Indore
# 1      TXN500001  CUST002326    2023-01-16   19  Female  Bhubaneswar
# 2      TXN500002  CUST002680    2023-01-24   40    Male    Bangalore
# 3      TXN500003  CUST001098    2024-09-06   46  Female    Ahmedabad
# 4      TXN500004  CUST003158    2023-10-18   62  Female         Pune
#
#   Online/Offline       Online Store     Category Item Purchased  Quantity
# 0        Offline  In-Store Purchase     Clothing          Jeans         1
# 1         Online               Ajio     Clothing         Jacket         1
# 2         Online             Myntra     Clothing          Saree         1
# 3        Offline  In-Store Purchase     Clothing          Jeans         1
# 4         Online           Flipkart  Accessories           Belt         1

# %%
df.tail()
# Out:
#      Transaction ID Customer ID Purchase Date  Age  Gender Location  \
# 9995      TXN509995  CUST000550    2023-12-21   64    Male  Lucknow
# 9996      TXN509996  CUST003122    2024-05-17   35  Female  Lucknow
# 9997      TXN509997  CUST003322    2024-05-06   34    Male    Noida
# 9998      TXN509998  CUST000523    2023-08-22   36  Female    Patna
# 9999      TXN509999  CUST001343    2024-01-19   33  Female   Mumbai
#
#      Online/Offline       Online Store  Category Item Purchased  Quantity
# 9995         Online             Amazon  Clothing         Shorts         1
# 9996        Offline  In-Store Purchase  Clothing       Trousers         1
# 9997         Online             Amazon  Footwear       Sneakers         1
# 9998         Online             Meesho  Footwear       Sneakers         2
# 9999         Online           Flipkart  Footwear          Heels         1

# %%
df.shape
# Out:
# (10000, 11)

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Customer ID', 'Purchase Date', 'Age', 'Gender',
#        'Location', 'Online/Offline', 'Online Store', 'Category',
#        'Item Purchased', 'Quantity'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Transaction ID  10000 non-null  object
#  1   Customer ID     10000 non-null  object
#  2   Purchase Date   10000 non-null  object
#  3   Age             10000 non-null  int64
#  4   Gender          10000 non-null  object
#  5   Location        10000 non-null  object
#  6   Online/Offline  10000 non-null  object
#  7   Online Store    10000 non-null  object
#  8   Category        10000 non-null  object
#  9   Item Purchased  10000 non-null  object
#  10  Quantity        10000 non-null  int64
# dtypes: int64(2), object(9)
# memory usage: 859.5+ KB

# %%
df.describe()
# Out:
#                 Age      Quantity
# count  10000.000000  10000.000000
# mean      41.095400      1.425900
# std       13.537475      0.725921
# min       18.000000      1.000000
# 25%       29.000000      1.000000
# 50%       41.000000      1.000000
# 75%       53.000000      2.000000
# max       64.000000      4.000000

# %%
df.isnull().sum()
# Out:
# Transaction ID    0
# Customer ID       0
# Purchase Date     0
# Age               0
# Gender            0
# Location          0
# Online/Offline    0
# Online Store      0
# Category          0
# Item Purchased    0
# Quantity          0
# dtype: int64

# %%
df.dtypes
# Out:
# Transaction ID    object
# Customer ID       object
# Purchase Date     object
# Age                int64
# Gender            object
# Location          object
# Online/Offline    object
# Online Store      object
# Category          object
# Item Purchased    object
# Quantity           int64
# dtype: object

# %% [markdown]
# # #data visualization

# %%
#Bar Chart
df['Gender'].value_counts().plot(kind='bar')
plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %%
#histogram
df['Age'].plot(kind='hist',color='pink')
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %%
#count plot
plt.figure(figsize=(6,4))
sns.countplot(x="Gender", data=df)
plt.title("Gender Distribution")
plt.show()

# %%
#scatterplot
plt.figure(figsize=(7,5))
plt.scatter(df["Age"], df["Quantity"])
plt.title("Age vs Quantity")
plt.xlabel("Age")
plt.ylabel("Quantity")
plt.show()

# %%
#heat map
numeric = df.select_dtypes(include="number")
plt.figure(figsize=(6,4))
sns.heatmap(numeric.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
#Pie Chart
online_offline = df['Online/Offline'].value_counts()
plt.figure(figsize=(6,6))
plt.pie(online_offline,
        labels=online_offline.index,
        autopct='%1.1f%%',
        startangle=90,
        colors=['skyblue', 'lightgreen'])

plt.title("Online vs Offline Shopping")
plt.show()
