# %% [markdown]
# <a href="https://colab.research.google.com/github/samikshak02/Python-Basic-Projects./blob/master/Optianaltak18_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Loading & Initial Analysis

# %%
from google.colab import files
uploaded= files.upload()
filepath="/content/anime-selected-columns.csv"
df=pd.read_csv(filepath)
# Out:
#      <input type="file" id="files-2e6cd862-4a28-4f1e-9d53-dc7fc906881a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2e6cd862-4a28-4f1e-9d53-dc7fc906881a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.head()
# Out:
#    anime_id                         title  score  rank  popularity  members  \
# 0     28977                      Gintama°   9.05     8         347   680037
# 1     57555  Chainsaw Man Movie: Reze-hen   9.18     2         962   282129
# 2     11061        Hunter x Hunter (2011)   9.03     9           8  3107455
# 3     52991             Sousou no Frieren   9.29     1         121  1269074
# 4      9969                      Gintama'   9.02    11         406   601940
#
#                                             synopsis  start_date    end_date  \
# 0  Gintoki, Shinpachi, and Kagura return as the f...  2015-01-01  2016-01-01
# 1                           Sequel to Chainsaw Man .  2025-01-01  2025-01-01
# 2  Hunters devote themselves to accomplishing haz...  2011-01-01  2014-01-01
# 3  During their decade-long quest to defeat the D...  2023-01-01  2024-01-01
# 4  After a one-year hiatus, Shinpachi Shimura ret...  2011-01-01  2012-01-01
#
#     type
# 0     TV
# 1  Movie
# 2     TV
# ...

# %%
df.tail()
# Out:
#       anime_id                                              title  score  \
# 9995      1351                                          Angel Cop   6.05
# 9996     33339                          Zhongguo Jingqi Xiansheng   6.05
# 9997      2840                              Youkoso Lodoss-tou e!   6.05
# 9998     33764                                 Ying Xiong Bie Nao   6.05
# 9999     49700  Arifureta Shokugyou de Sekai Saikyou Picture D...   6.05
#
#       rank  popularity  members  \
# 9995  9994        4755    26983
# 9996  9991       10781     3192
# 9997  9988       11348     2710
# 9998  9987       17963      502
# 9999  9996       10448     3510
#
#                                                synopsis  start_date  \
# 9995  Sometime in the future, terrorism in Japan has...  1989-01-01
# 9996  A lost form of magic is revived from the Easte...  2014-01-01
# 9997  This movie is the compilation of the 27 mini-p...  1998-01-01
# ...

# %%
df.shape
# Out:
# (10000, 10)

# %%
df.dtypes
# Out:
# anime_id        int64
# title          object
# score         float64
# rank            int64
# popularity      int64
# members         int64
# synopsis       object
# start_date     object
# end_date       object
# type           object
# dtype: object

# %% [markdown]
# ## Missing & Duplicate Values

# %%
print("Duplicate Rows:", df.duplicated().sum())
# Out:
# Duplicate Rows: 1

# %%
df = df.drop_duplicates()

# %%
print("New Shape:", df.shape)
# Out:
# New Shape: (9999, 10)

# %% [markdown]
# # Statistical Summary

# %%
df.describe()
# Out:
#            anime_id        score          rank    popularity       members
# count   9999.000000  9999.000000   9999.000000   9999.000000  9.999000e+03
# mean   24127.352335     6.980561   5000.679268   6490.504650  1.075413e+05
# std    19948.395388     0.619431   2886.983645   4646.370323  2.733630e+05
# min        1.000000     6.050000      1.000000      1.000000  2.260000e+02
# 25%     4055.000000     6.470000   2500.500000   2591.500000  4.272500e+03
# 50%    21405.000000     6.900000   5001.000000   5564.000000  1.818900e+04
# 75%    40026.000000     7.390000   7500.500000   9823.500000  8.469750e+04
# max    62863.000000     9.290000  10000.000000  22184.000000  4.262220e+06

# %%
df[['score','popularity','members']].min()
# Out:
# score           6.05
# popularity      1.00
# members       226.00
# dtype: float64

# %%
df[['score','popularity','members']].max()
# Out:
# score               9.29
# popularity      22184.00
# members       4262220.00
# dtype: float64

# %%
df[['score','popularity','members']].mean()
# Out:
# score              6.980561
# popularity      6490.504650
# members       107541.282628
# dtype: float64

# %%
df[['score','popularity','members']].median()
# Out:
# score             6.9
# popularity     5564.0
# members       18189.0
# dtype: float64

# %% [markdown]
# # Histogram of Numeric Features

# %%
sns.histplot(df['score'])
plt.title('score Distribution')
plt.xlabel('score')
plt.ylabel('Frequency')
plt.show()

# %%
sns.histplot(df["popularity"])
plt.title("popularity Distribution")
plt.xlabel("popularity")
plt.ylabel("Count")
plt.show()

# %%
sns.histplot(df["members"])
plt.title("memberss Distribution")
plt.xlabel("members")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # Count Plots of Categorical Features

# %%
sns.countplot(x="type", data=df)
plt.title("Type Count")
plt.xlabel("Type")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # Correlation Heatmap

# %%
sns.heatmap(df.corr(numeric_only=True))
plt.title("Heatmap")
plt.show()

# %% [markdown]
# # Identify input and output features .

# %%
X = df.drop('members', axis=1)
Y = df['members']

print("input Features:")
print(X.columns)
print("\nOutput Feature:")
print(Y.name)
# Out:
# input Features:
# Index(['anime_id', 'title', 'score', 'rank', 'popularity', 'synopsis',
#        'start_date', 'end_date', 'type'],
#       dtype='object')
#
# Output Feature:
# members

# %% [markdown]
# # Encoding Categorical Variables

# %%
encoded= pd.get_dummies(df)
print(encoded.head())
# Out:
#    anime_id  score  rank  popularity  members  \
# 0     28977   9.05     8         347   680037
# 1     57555   9.18     2         962   282129
# 2     11061   9.03     9           8  3107455
# 3     52991   9.29     1         121  1269074
# 4      9969   9.02    11         406   601940
#
#    title_"Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi  \
# 0                                            False
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
#
#    title_"Bungaku Shoujo" Memoire  title_"Bungaku Shoujo" Movie  \
# 0                           False                         False
# 1                           False                         False
# 2                           False                         False
# 3                           False                         False
# ...
